# %%
import yfinance as yf
import plotly.express as px

# %%
missing = df.isnull().sum()
print(missing)

nan = df.isna().sum()
print(nan)

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df < lower_bound) | (df > upper_bound)]
print(outliers)
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
#                            Open  High  Low  Close  Volume  Dividends  \
# Date
# 2016-03-11 00:00:00-05:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2016-03-14 00:00:00-04:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2016-03-15 00:00:00-04:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2016-03-16 00:00:00-04:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2016-03-17 00:00:00-04:00   NaN   NaN  NaN    NaN     NaN        NaN
# ...                         ...   ...  ...    ...     ...        ...
# 2026-03-04 00:00:00-05:00   NaN   NaN  NaN    NaN     NaN        NaN
# 2026-03-05 00:00:00-05:00   NaN   NaN  NaN    NaN     NaN        NaN
# ...

# %%
fig = px.scatter(df, y = "Close", title = 'Closing Price of AAPL Over the Past 10 Years')
fig.show()

# %%
csvFile1 = '../Data/AAPL_Close_Price.csv'
df['Close'].to_csv(csvFile1, index = True)

csvFile2 = '../Data/AAPL_Stock_Info.csv'
df.to_csv(csvFile2, index = True)

# %%
from SegmentData import yearBreakup, monthlyAvg
from returns import simpleReturns, AvgMonthlyReturns

# yearBreakup('../Data/AAPL_Stock_Info.csv', '../Data/Year_Month_AAPL.csv')
# yearBreakup('../Data/AAPL_Close_Price.csv', '../Data/Year_Month_AAPL_Close.csv')

# monthlyAvg('../Data/Year_Month_AAPL_Close.csv', 'Close', '../Data/monthlyAverage.csv', 'Close(Average)')

# simpleReturns('../Data/Year_Month_AAPL_Close.csv', 'Close', '../Data/Simple_Returns.csv', 'Simple Returns')
# AvgMonthlyReturns('../Data/monthlyAverage.csv', 'Close(Average)', '../Data/Avg_Monthly_Returns.csv', 'Avg Monthly Returns')

# %%
from Plotting import scatterPlot
scatterPlot('../Data/monthlyAverage.csv', 'Monthly Average Closing Price of AAPL Over the Past 10 Years', 'Close(Average)', 'Year-Month')

scatterPlot('../Data/AAPL_Stock_info.csv', 'Closing Price of AAPL Over the Past 10 Years', 'Close', 'Date')
