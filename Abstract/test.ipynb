# %%
from market_test import overall_analysis

overall_analysis("NVDA", "2020-03-12", "2026-03-12", "Close", 183.16, 287, 10000, 'blue', 'pink')
overall_analysis("SPY", "2020-03-12", "2026-03-12", "Close", 666.06, 287, 10000, 'red', 'purple')
# Out:
# AIC TEST:
#    Distribution:          AIC          BIC  \
# 3      johnsonsu  7713.395868  7734.664717
# 4  genhyperbolic  7713.828191  7740.414254
# 1              t  7721.542358  7737.493996
# 5      hypsecant  7729.468408  7740.102833
# 2        laplace  7762.643804  7773.278229
# 6       skewnorm  7875.107643  7891.059280
# 0           norm  7884.725425  7895.359850
# 7         cauchy  8070.159910  8080.794335
#
#                                               Params  Param Quantity
# 3  (-0.0893413889674545, 1.5728459704778461, 0, 4...               4
# 4  (-2.5158123999602715, 0.15425722551745108, 0.1...               5
# 1          (4.919035912673789, 0, 2.535898369682203)               3
# 5                             (0, 2.070266711529941)               2
# 2                             (0, 2.417572112077872)               2
# 6        (0.11128605642933603, 0, 3.311875488246016)               3
# 0                             (0, 3.311840810897047)               2
# ...
