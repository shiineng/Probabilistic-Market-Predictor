# %%
from market_test import overall_analysis

overall_analysis("AAPL", "2015-03-21", "2025-04-01", "Close", 277, 10000, 'blue', 'pink', None)
# Out:
# Starting Monte Carlo at most recent known price (2025-04-01): $221.17
# AIC TEST:
#    Distribution:           AIC           BIC  \
# 3      johnsonsu   9674.444562   9697.774206
# 4  genhyperbolic   9678.361501   9707.523556
# 1              t   9689.787059   9707.284292
# 2        laplace   9693.116288   9704.781110
# 5      hypsecant   9713.509845   9725.174667
# 6       skewnorm  10108.139798  10125.637030
# 7         cauchy  10111.236665  10122.901487
# 0           norm  10113.606590  10125.271412
#
#                                               Params  Param Quantity
# 3  (-0.06614435256136425, 1.2297736163945139, 0, ...               4
# 4  (-0.27504146755369796, 0.6449802354650824, 0.0...               5
# 1            (3.383577050185468, 0, 1.2079396614176)               3
# 2                            (0, 1.2567561982339728)               2
# 5                            (0, 1.0788063829477448)               2
# ...
