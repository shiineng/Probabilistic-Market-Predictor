# %%
from market_test import overall_analysis

overall_analysis("AAPL", "2016-03-13", "2026-03-13", "Close", 253.51, 365, 10000, 'blue', 'pink')
# Out:
# AIC TEST:
#    Distribution:           AIC           BIC  \
# 3      johnsonsu   9612.267911   9635.584841
# 4  genhyperbolic   9617.196767   9646.342930
# 1              t   9632.288477   9649.776175
# 2        laplace   9637.582685   9649.241150
# 5      hypsecant   9676.654907   9688.313372
# 7         cauchy  10013.361058  10025.019523
# 6       skewnorm  10151.407418  10168.895116
# 0           norm  10158.924321  10170.582786
#
#                                               Params  Param Quantity
# 3  (-0.07466985180915926, 1.1556028951812047, 0, ...               4
# 4  (-0.3082420951289893, 0.5407444660529487, 0.04...               5
# 1        (3.0762534485449593, 0, 1.1629733873594659)               3
# 2                            (0, 1.2505735166412772)               2
# 5                             (0, 1.073471090386285)               2
# 7                            (0, 0.8079339607059594)               2
# ...
